# %%
import matplotlib as plt 
import pandas as pd 
data=pd.read_csv('india_covid_19.csv')
data['State/UnionTerritory'].value_counts().plot.pie()

# %%
import matplotlib as plt 
import pandas as pd 
data=pd.read_csv('india_covid_19.csv')
data.plot(kind='line',x='Deaths',y='Confirmed')

# %%
import matplotlib.pyplot as plt 
import pandas as pd 
age=pd.read_csv('AgeGroupDetails.csv')
plt.bar(age['Percentage'],age['TotalCases'])
plt.show()

# %%
import matplotlib as plt 
import pandas as pd 
gn=pd.read_csv('IndividualDetails.csv')
plt.bar(df['gender'],df['age'] )
plt.set_xlabel("Age")
plt.set_ylabel("Total")
plt.set_title("Gender wise total cases")
plt.show()
